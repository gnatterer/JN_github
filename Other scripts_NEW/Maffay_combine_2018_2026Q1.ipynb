# %% [markdown]
# # Maffay — combine Q4 2017–2026 Q1 (digital + physical)
#
# Reads every workbook in `as received 20260916` except the 2023 notes file. Q4 2017 line items are one former tab per `.xlsx` file; the 2017 summary workbook is skipped. Maps columns from **Translation tables.xlsx** (P–V), derives the red-font date fields (notes below row 28), then harmonises DSPs (`DSP.xlsx`), titles (`Title.xlsx`), countries (`Country.xlsx`), income type (`Income_type.xlsx`) and source (`Source.xlsx`).
#
# Outputs go to `/Users/johannesnatterer/Developer/_output`:
#
# - `Maffay_2018_2026Q1_combined_harmonised.csv` — full combined table (too large for Excel’s row limit)
# - `Maffay_2018_2026Q1_filtered_titles.xlsx` — rows for the titles in `FILTER_TITLES` (written only if that list is not empty)
# - `Maffay_2018_2026Q1_combined_harmonised_first1000.xlsx` — first 1,000 rows
# - `Maffay_2018_2026Q1_control_check.xlsx` — combined Net Amount vs the amount column on each mapped source tab (Q1 2026 first, then older files)
# - `Maffay_2018_2026Q1_unmatched_DSP.xlsx` / `Maffay_2018_2026Q1_unmatched_titles.xlsx` / `Maffay_2018_2026Q1_unmatched_countries.xlsx` / `Maffay_2018_2026Q1_unmatched_income_type.xlsx` / `Maffay_2018_2026Q1_unmatched_source.xlsx` — written only if there are unmatched values
#
# In the first code cell: `LOAD_COMBINED_CSV = True` reads the existing combined CSV instead of rebuilding from the quarterly workbooks; `FILTER_TITLES` is a comma-separated list of `Product Title (harmonised)` values to export. **Run All**, or run the last cells on their own after the CSV exists.

# %%
import re
import warnings
from pathlib import Path

import numpy as np
import pandas as pd

warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl")

onedrive_root = Path.home() / "Library/CloudStorage/OneDrive-NattererLabs"
maffay_root = onedrive_root / "22 Fullstream Music/202607. Peter Maffay"
as_received = maffay_root / "Data/as received 20260916"
lookup_dir = maffay_root / "Data/lookup"
output_root = Path("/Users/johannesnatterer/Developer/_output")
output_root.mkdir(parents=True, exist_ok=True)

combined_csv = output_root / "Maffay_2018_2026Q1_combined_harmonised.csv"
combined_first1000 = output_root / "Maffay_2018_2026Q1_combined_harmonised_first1000.xlsx"
pivot_xlsx = output_root / "Maffay_2018_2026Q1_combined_pivot.xlsx"
unmatched_dsp_xlsx = output_root / "Maffay_2018_2026Q1_unmatched_DSP.xlsx"
unmatched_titles_xlsx = output_root / "Maffay_2018_2026Q1_unmatched_titles.xlsx"
unmatched_countries_xlsx = output_root / "Maffay_2018_2026Q1_unmatched_countries.xlsx"
unmatched_income_type_xlsx = output_root / "Maffay_2018_2026Q1_unmatched_income_type.xlsx"
unmatched_source_xlsx = output_root / "Maffay_2018_2026Q1_unmatched_source.xlsx"
control_xlsx = as_received / "Red Rooster Q1 2026 Abrechnung.xlsx"
check_xlsx = output_root / "Maffay_2018_2026Q1_control_check.xlsx"
filtered_xlsx = output_root / "Maffay_2018_2026Q1_filtered_titles.xlsx"

# a) True = load the existing combined CSV. False = rebuild from the quarterly workbooks.
LOAD_COMBINED_CSV = False

# b) Comma-separated Product Title (harmonised) values to export to xlsx. Leave empty to skip.
FILTER_TITLES = ""   # e.g. "Tattoos - Live, Tabaluga"

# Set this to False if you do not want the source-file check to run.
RUN_SOURCE_CHECK = True

print("as received:      ", as_received)
print("lookup:           ", lookup_dir)
print("output:           ", output_root)
print("LOAD_COMBINED_CSV:", LOAD_COMBINED_CSV)
print("FILTER_TITLES:    ", FILTER_TITLES or "(none)")
print("RUN_SOURCE_CHECK: ", RUN_SOURCE_CHECK)

# Translation tables.xlsx column V (mapped list)
CANONICAL = [
    "Tab Name",
    "File Name",
    "Artist",
    "Product Title",
    "ISRC",
    "Reporting Quarter",
    "Reporting Month",
    "Sales Quarter",
    "Sales Month",
    "Distribution Channel",
    "Distribution Manner",
    "Third Party / DSP",
    "Third Party / DSP (Product)",
    "Net Invoice Price",
    "Received Rate %",
    "Amount per Unit",
    "SAP Sales Units",
    "Net Amount",
    "Country of Sale",
    "Product Configuration",
]

SKIP_FILE_PATTERNS = ("erläuterung", "erlauterung")
SKIP_SHEET_PATTERNS = (
    "rechnungsstellung",
    "analyse",
    "anaylse",
    "manufacturing",
    "hidden",
    "steuerliche",
    "m&p",
)


def skip_file(path):
    name = path.name.lower()
    if any(p in name for p in SKIP_FILE_PATTERNS):
        return True
    # Q4 2017 Red Rooster.xlsx is the summary workbook; line items live in the per-tab xlsx files.
    if name == "q4 2017 red rooster.xlsx":
        return True
    if path.suffix.lower() == ".xls" and path.with_suffix(".xlsx").exists():
        return True
    return False


def canonical_tab_name(path, sheet):
    """Q4 2017 stores each 2018-style tab as its own workbook."""
    name = path.name.lower()
    if "2017" not in name:
        return sheet
    is_mtv = "mtv" in name
    if "digital" in name:
        return "dig.GSA Red Rooster MTV Unpl." if is_mtv else "digital GSA Red Rooster"
    if "physical" in name:
        return "phys.GSA Red Rooster MTV Unpl." if is_mtv else "physisch GSA Red Rooster"
    return sheet


def skip_sheet(name):
    n = (name or "").lower()
    if n.startswith("xl_") or n.startswith("_com."):
        return True
    return any(p in n for p in SKIP_SHEET_PATTERNS)


def normalize_header(value):
    if value is None or (isinstance(value, float) and pd.isna(value)):
        return ""
    text = str(value).replace("\n", " ").replace("\r", " ").strip()
    return re.sub(r"\s+", " ", text)


def find_col(df, *candidates):
    lookup = {normalize_header(c).casefold(): c for c in df.columns}
    for candidate in candidates:
        key = normalize_header(candidate).casefold()
        if key in lookup:
            return lookup[key]
    return None


def series(df, *candidates):
    found = find_col(df, *candidates)
    if found is None:
        return pd.Series(pd.NA, index=df.index)
    return df[found]


def to_num(s):
    return pd.to_numeric(s, errors="coerce")


def to_year(s):
    return to_num(s)


def to_month(s):
    return to_num(s)


def yyyy_mm(year, month):
    """Format W/X example: 2025 12."""
    y = to_year(year)
    m = to_month(month)
    result = pd.Series(pd.NA, index=year.index, dtype="object")
    mask = y.notna() & m.notna() & (m >= 1) & (m <= 12)
    result.loc[mask] = (
        y.loc[mask].astype(int).astype(str)
        + " "
        + m.loc[mask].astype(int).astype(str).str.zfill(2)
    )
    return result


def month_to_quarter(month_series):
    """Turn 'YYYY MM' into 'YYYY QN' (translation table W/X)."""
    result = pd.Series(pd.NA, index=month_series.index, dtype="object")
    mask = month_series.notna()
    if not mask.any():
        return result
    parts = month_series.loc[mask].astype(str).str.split(" ", n=1, expand=True)
    if parts.shape[1] < 2:
        return result
    month_n = pd.to_numeric(parts[1], errors="coerce")
    ok = month_n.notna() & (month_n >= 1) & (month_n <= 12)
    if not ok.any():
        return result
    quarters = ((month_n.loc[ok].astype(int) - 1) // 3 + 1).astype(str)
    result.loc[parts.index[ok]] = parts.loc[ok, 0].astype(str) + " Q" + quarters
    return result


def parse_qn_token(value):
    """Parse 'Q1-2018', '2018 Q1', '1. Quartal 2018' → (year, 'Q1')."""
    if value is None or (isinstance(value, float) and pd.isna(value)):
        return (np.nan, np.nan)
    text = str(value).strip()
    m = re.search(r"(20\d{2})\s*Q\s*([1-4])", text, flags=re.I)
    if m:
        return (int(m.group(1)), f"Q{m.group(2)}")
    m = re.search(r"Q\s*([1-4])\s*[-/ ]\s*(20\d{2})", text, flags=re.I)
    if m:
        return (int(m.group(2)), f"Q{m.group(1)}")
    m = re.search(r"([1-4])\.\s*Quartal\s*(20\d{2})", text, flags=re.I)
    if m:
        return (int(m.group(2)), f"Q{m.group(1)}")
    return (np.nan, np.nan)


def qn_yyyy_to_yyyy_qq(series_in):
    parsed = series_in.map(parse_qn_token)
    result = pd.Series(pd.NA, index=series_in.index, dtype="object")
    years = parsed.map(lambda t: t[0])
    qs = parsed.map(lambda t: t[1])
    mask = years.notna() & qs.notna()
    result.loc[mask] = years.loc[mask].astype(int).astype(str) + " " + qs.loc[mask].astype(str)
    already = series_in.astype(str).str.match(r"^\s*20\d{2}\s+Q[1-4]\s*$", na=False)
    result.loc[already & result.isna()] = series_in.loc[already & result.isna()].astype(str).str.strip()
    return result


def year_from_qn(series_in):
    parsed = series_in.map(parse_qn_token)
    years = parsed.map(lambda t: t[0])
    numeric = to_year(series_in)
    out = pd.to_numeric(years, errors="coerce")
    out = out.fillna(numeric)
    return out


NUMERIC_COLS = {
    "Net Invoice Price",
    "Received Rate %",
    "Amount per Unit",
    "SAP Sales Units",
    "Net Amount",
}


def empty_canonical(index):
    data = {}
    for column in CANONICAL:
        if column in NUMERIC_COLS:
            data[column] = pd.Series(np.nan, index=index, dtype="float64")
        else:
            data[column] = pd.Series(pd.NA, index=index, dtype="object")
    return pd.DataFrame(data)


def drop_trailing_summary(df):
    if df.empty:
        return df
    first_col = df.columns[0]
    last_valid = df[first_col].last_valid_index()
    if last_valid is None:
        return df.iloc[0:0]
    if last_valid < len(df) - 1:
        return df.loc[:last_valid]
    return df


def classify_sheet(df, sheet_name):
    """Map a sheet to translation-table groups P / Q / R / S / T / U."""
    if find_col(df, "WHOLESALE_VALUE"):
        return "P"
    if find_col(df, "Net Amount"):
        return "Q"
    sheet_l = (sheet_name or "").lower()
    is_phys = "phys" in sheet_l
    if find_col(df, "Abrechnungsmonat") or find_col(df, "Verkaufsland") or is_phys:
        if find_col(df, "Jahr") and not find_col(df, "Abrechnungsmonat"):
            return "S"
        if find_col(df, "Abrechnungsmonat"):
            sample = series(df, "Abrechnungsmonat").dropna().head(20)
            looks_qn = sample.astype(str).str.contains(r"Q\s*[1-4]", case=False, na=False).any()
            return "R" if looks_qn else "S"
        if is_phys and find_col(df, "Monat"):
            return "S"
    if find_col(df, "Zeitraum") and (find_col(df, "ISRC") or find_col(df, "Expr1003")):
        if find_col(df, "Expr1003") and not find_col(df, "ISRC"):
            return "U"
        return "T"
    return None


def map_group_p(df):
    """WHOLESALE_VALUE tabs (digital GSA from 2020 Q4)."""
    out = empty_canonical(df.index)
    out["Artist"] = series(df, "INTERPRET")
    out["Product Title"] = series(df, "TITEL")
    out["ISRC"] = series(df, "ISRC")
    reporting_month = yyyy_mm(series(df, "Jahr"), series(df, "Monat"))
    sales_month = yyyy_mm(series(df, "EMD_YR"), series(df, "EMD_PERIOD_ID"))
    out["Reporting Month"] = reporting_month
    out["Reporting Quarter"] = month_to_quarter(reporting_month)
    out["Sales Month"] = sales_month
    out["Sales Quarter"] = month_to_quarter(sales_month)
    out["Distribution Channel"] = series(df, "PARENT_SALES_CAT_DC")
    out["Distribution Manner"] = series(df, "SALES_CATEGORY_DC")
    out["Third Party / DSP"] = series(df, "PROVIDER_NAME")
    out["Third Party / DSP (Product)"] = series(df, "VENDOR_NAME")
    out["SAP Sales Units"] = to_num(series(df, "QUANTITY"))
    out["Net Amount"] = to_num(series(df, "WHOLESALE_VALUE"))
    out["Country of Sale"] = series(df, "COUNTRY_SALE")
    out["Product Configuration"] = series(df, "TONTRAEGER_BEZ")
    return out


def map_group_q(df):
    """Net Amount tabs (Ex-GSA, GVL, Kopplungserlöse)."""
    out = empty_canonical(df.index)
    out["Artist"] = series(df, "Product Main Artist")
    out["Product Title"] = series(df, "Product Title")
    out["ISRC"] = series(df, "ISRC")
    out["Reporting Quarter"] = qn_yyyy_to_yyyy_qq(series(df, "Accounting Period"))
    out["Reporting Month"] = series(df, "Reported Period")
    out["Sales Quarter"] = qn_yyyy_to_yyyy_qq(series(df, "Sales Period"))
    out["Distribution Channel"] = series(df, "Distribution Channel")
    out["Distribution Manner"] = series(df, "Distribution Manner")
    out["Third Party / DSP"] = series(df, "Third Party / DSP")
    out["Net Invoice Price"] = to_num(series(df, "Net Invoice Price"))
    out["Received Rate %"] = to_num(series(df, "Received Rate %"))
    out["Amount per Unit"] = to_num(series(df, "Amount per Unit"))
    out["SAP Sales Units"] = to_num(series(df, "SAP Sales Units"))
    out["Net Amount"] = to_num(series(df, "Net Amount"))
    out["Country of Sale"] = series(df, "Country of Sale")
    out["Product Configuration"] = series(df, "Product Configuration")
    return out


def physical_amount(df):
    """Net Amount for physical tabs: Translation tables R22/S22 = Nettoumsatz Vormonat."""
    return to_num(series(df, "Nettoumsatz Vormonat"))


def map_physical(df, reporting_month, reporting_quarter):
    out = empty_canonical(df.index)
    out["Artist"] = series(df, "Interpret")
    out["Product Title"] = series(df, "Titel")
    out["Reporting Quarter"] = reporting_quarter
    out["Reporting Month"] = reporting_month
    out["Distribution Channel"] = series(df, "Verkaufsweg")
    out["Amount per Unit"] = to_num(series(df, "HAP"))
    out["SAP Sales Units"] = to_num(series(df, "Nettoabsatz Vormonat"))
    out["Net Amount"] = physical_amount(df)
    out["Country of Sale"] = series(df, "Verkaufsland", "Tontr#")
    out["Product Configuration"] = series(df, "Raas Tontraeger Kat Bez", "Tontr#Kat#Bez")
    return out


def map_group_r(df):
    """Physical until ~2025 Q3: Abrechnungsmonat + Monat."""
    abr = series(df, "Abrechnungsmonat")
    year = year_from_qn(abr)
    month = to_month(series(df, "Monat"))
    reporting_month = yyyy_mm(year, month)
    reporting_quarter = qn_yyyy_to_yyyy_qq(abr)
    missing_q = reporting_quarter.isna() & reporting_month.notna()
    reporting_quarter.loc[missing_q] = month_to_quarter(reporting_month.loc[missing_q])
    return map_physical(df, reporting_month, reporting_quarter)


def map_group_s(df):
    """Physical from 2025 Q4: Jahr + Monat (or Abrechnungsmonat holding a year)."""
    year = to_year(series(df, "Jahr"))
    if year.isna().all():
        year = to_year(series(df, "Abrechnungsmonat"))
    month = to_month(series(df, "Monat"))
    reporting_month = yyyy_mm(year, month)
    reporting_quarter = month_to_quarter(reporting_month)
    return map_physical(df, reporting_month, reporting_quarter)


def map_group_tu(df):
    """Digital 2018–2020 Q3: Zeitraum + Monat. ISRC or Expr1003."""
    out = empty_canonical(df.index)
    out["Artist"] = series(df, "Interpret")
    out["Product Title"] = series(df, "Titel")
    out["ISRC"] = series(df, "ISRC", "Expr1003")
    zeitraum = series(df, "Zeitraum")
    year = year_from_qn(zeitraum)
    month = to_month(series(df, "Monat"))
    reporting_month = yyyy_mm(year, month)
    reporting_quarter = qn_yyyy_to_yyyy_qq(zeitraum)
    missing_q = reporting_quarter.isna() & reporting_month.notna()
    reporting_quarter.loc[missing_q] = month_to_quarter(reporting_month.loc[missing_q])
    out["Reporting Quarter"] = reporting_quarter
    out["Reporting Month"] = reporting_month
    out["Distribution Channel"] = series(df, "EMD_Parent_Sales_Cat_Bez")
    out["SAP Sales Units"] = to_num(series(df, "Nettoabs#"))
    out["Net Amount"] = to_num(series(df, "Netto-Ums#"))
    out["Country of Sale"] = series(df, "Land")
    out["Product Configuration"] = series(df, "Tontr#Kat#Bez")
    return out


MAPPERS = {
    "P": map_group_p,
    "Q": map_group_q,
    "R": map_group_r,
    "S": map_group_s,
    "T": map_group_tu,
    "U": map_group_tu,
}


def load_sheet(path, sheet):
    df = pd.read_excel(path, sheet_name=sheet)
    if df.empty:
        return df
    df.columns = [normalize_header(c) for c in df.columns]
    df = df.loc[:, ~pd.Index(df.columns).duplicated()]
    unnamed = [c for c in df.columns if not c or str(c).lower().startswith("unnamed")]
    if unnamed:
        df = df.drop(columns=unnamed, errors="ignore")
    df = drop_trailing_summary(df)
    df = df.dropna(how="all")
    return df.reset_index(drop=True)


def process_workbook(path):
    frames = []
    try:
        xl = pd.ExcelFile(path)
    except Exception as exc:
        print(f"  SKIP file (cannot open): {path.name} — {exc}")
        return frames
    for sheet in xl.sheet_names:
        if skip_sheet(sheet):
            continue
        try:
            df = load_sheet(path, sheet)
        except Exception as exc:
            print(f"  SKIP sheet {path.name} / {sheet!r}: {exc}")
            continue
        if df.empty or len(df.columns) < 4:
            continue
        group = classify_sheet(df, sheet)
        if group is None:
            looks_like_data = any(
                k in f"{sheet} {path.name}".lower()
                for k in ("phys", "dig", "gvl", "kopplung", "musical")
            )
            if looks_like_data:
                print(f"  UNMAPPED {path.name} / {sheet!r}  cols={list(df.columns)[:8]}")
            continue
        mapped = MAPPERS[group](df)
        mapped["Tab Name"] = canonical_tab_name(path, sheet)
        mapped["File Name"] = path.name
        mapped["Source Group"] = group
        frames.append(mapped)
        extra = ""
        if group in ("R", "S"):
            extra = f"  Net Amount={find_col(df, 'Nettoumsatz Vormonat')!r}"
        print(f"  {group}  {path.name} / {sheet!r}  → {len(mapped):,} rows{extra}")
    return frames
# Out:
# as received:       /Users/johannesnatterer/Library/CloudStorage/OneDrive-NattererLabs/22 Fullstream Music/202607. Peter Maffay/Data/as received 20260916
# lookup:            /Users/johannesnatterer/Library/CloudStorage/OneDrive-NattererLabs/22 Fullstream Music/202607. Peter Maffay/Data/lookup
# output:            /Users/johannesnatterer/Developer/_output
# LOAD_COMBINED_CSV: False
# FILTER_TITLES:     (none)
# RUN_SOURCE_CHECK:  True

# %%
# Loading the raw input files is slow (large workbooks), so this only runs
# once per kernel session unless LOAD_COMBINED_CSV is True.
# Re-run this cell after a kernel restart, or if the input files themselves changed.
PHYSICAL_NET_AMOUNT_COL = "Nettoumsatz Vormonat"

if LOAD_COMBINED_CSV:
    if not combined_csv.exists():
        raise FileNotFoundError(
            f"Combined file not found: {combined_csv}\n"
            "Set LOAD_COMBINED_CSV = False in the first code cell to rebuild it."
        )
    combined = pd.read_csv(combined_csv, low_memory=False)
    LOADED_FROM_CSV = True
    print(f"Loaded {len(combined):,} rows from {combined_csv}")
    if "Source Group" in combined.columns:
        print(combined.groupby("Source Group").size().rename("rows").to_string())
    print(f"Net Amount total: {pd.to_numeric(combined['Net Amount'], errors='coerce').sum():,.2f}")
else:
    LOADED_FROM_CSV = False
    if "all_frames" in globals() and globals().get("LOADED_PHYSICAL_COL") != PHYSICAL_NET_AMOUNT_COL:
        print("Cached frames still used Summe for physical Net Amount; reloading from source files.")
        del all_frames
    if "all_frames" in globals() and not globals().get("LOADED_INCLUDE_2017"):
        print("Cached frames exclude Q4 2017; reloading from source files.")
        del all_frames

    if "all_frames" not in globals():
        files = sorted(
            p
            for p in as_received.iterdir()
            if p.suffix.lower() in {".xlsx", ".xls", ".xlsm"}
            and not p.name.startswith("~$")
            and not skip_file(p)
        )
        print(f"{len(files)} workbooks to process\n")

        all_frames = []
        for i, path in enumerate(files, 1):
            print(f"[{i}/{len(files)}] {path.name}")
            all_frames.extend(process_workbook(path))

        if not all_frames:
            raise RuntimeError("No sheets were mapped. Check as-received files and skip rules.")

        print("\nFinished loading input files.")
        LOADED_PHYSICAL_COL = PHYSICAL_NET_AMOUNT_COL
        LOADED_INCLUDE_2017 = True
    else:
        print("Input files already loaded in memory; skipping reload (re-run this cell if the input files changed).")

    combined = pd.concat(all_frames, ignore_index=True)
    print(f"Combined rows before lookup: {len(combined):,}")
    print(combined.groupby("Source Group").size().rename("rows").to_string())
    print(f"Net Amount total: {pd.to_numeric(combined['Net Amount'], errors='coerce').sum():,.2f}")
# Out:
# Cached frames exclude Q4 2017; reloading from source files.
# 41 workbooks to process
#
# [1/41] 2018_Q1 2018 Red Rooster.xlsx
#   R  2018_Q1 2018 Red Rooster.xlsx / 'physisch GSA Red Rooster'  → 325 rows  Net Amount='Nettoumsatz Vormonat'
#   U  2018_Q1 2018 Red Rooster.xlsx / 'digital GSA Red Rooster'  → 8,524 rows
#   R  2018_Q1 2018 Red Rooster.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 66 rows  Net Amount='Nettoumsatz Vormonat'
#   T  2018_Q1 2018 Red Rooster.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 798 rows
# [2/41] 2018_Q2 2018 Red Rooster.xlsx
#   R  2018_Q2 2018 Red Rooster.xlsx / 'physisch GSA Red Rooster'  → 323 rows  Net Amount='Nettoumsatz Vormonat'
#   U  2018_Q2 2018 Red Rooster.xlsx / 'digital GSA Red Rooster'  → 9,495 rows
#   R  2018_Q2 2018 Red Rooster.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 69 rows  Net Amount='Nettoumsatz Vormonat'
#   T  2018_Q2 2018 Red Rooster.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 782 rows
# [3/41] 2018_Q3 2018  Red Rooster.xlsx
#   R  2018_Q3 2018  Red Rooster.xlsx / 'physisch GSA Red Rooster'  → 277 rows  Net Amount='Nettoumsatz Vormonat'
#   U  2018_Q3 2018  Red Rooster.xlsx / 'digital GSA Red Rooster'  → 6,012 rows
#   R  2018_Q3 2018  Red Rooster.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 66 rows  Net Amount='Nettoumsatz Vormonat'
#   T  2018_Q3 2018  Red Rooster.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 633 rows
# [4/41] 2018_Q4 2018 Red Rooster.xlsx
#   R  2018_Q4 2018 Red Rooster.xlsx / 'physisch GSA Red Rooster'  → 310 rows  Net Amount='Nettoumsatz Vormonat'
#   U  2018_Q4 2018 Red Rooster.xlsx / 'digital GSA Red Rooster'  → 9,778 rows
#   R  2018_Q4 2018 Red Rooster.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 68 rows  Net Amount='Nettoumsatz Vormonat'
#   T  2018_Q4 2018 Red Rooster.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 751 rows
# [5/41] 2019_Q1 2019 Red Rooster.xlsx
#   R  2019_Q1 2019 Red Rooster.xlsx / 'physisch GSA Red Rooster Kat.'  → 315 rows  Net Amount='Nettoumsatz Vormonat'
#   T  2019_Q1 2019 Red Rooster.xlsx / 'digital GSA Red Rooster Katalog'  → 10,188 rows
#   R  2019_Q1 2019 Red Rooster.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 77 rows  Net Amount='Nettoumsatz Vormonat'
#   T  2019_Q1 2019 Red Rooster.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 755 rows
# [6/41] 2019_Q2 2019 Red Rooster per Q2 2019.xlsx
#   R  2019_Q2 2019 Red Rooster per Q2 2019.xlsx / 'physisch GSA Red Rooster Kat.'  → 281 rows  Net Amount='Nettoumsatz Vormonat'
#   T  2019_Q2 2019 Red Rooster per Q2 2019.xlsx / 'digital GSA Red Rooster Katalog'  → 13,749 rows
#   R  2019_Q2 2019 Red Rooster per Q2 2019.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 65 rows  Net Amount='Nettoumsatz Vormonat'
#   T  2019_Q2 2019 Red Rooster per Q2 2019.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 966 rows
# [7/41] 2019_Q3 2019 Red Rooster.xlsx
#   R  2019_Q3 2019 Red Rooster.xlsx / 'physisch GSA Red Rooster Kat.'  → 343 rows  Net Amount='Nettoumsatz Vormonat'
#   T  2019_Q3 2019 Red Rooster.xlsx / 'digital GSA Red Rooster Katalog'  → 8,724 rows
#   R  2019_Q3 2019 Red Rooster.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 62 rows  Net Amount='Nettoumsatz Vormonat'
#   T  2019_Q3 2019 Red Rooster.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 517 rows
# [8/41] 2019_Q4 2019 Red Rooster.xlsx
#   R  2019_Q4 2019 Red Rooster.xlsx / 'physisch GSA Red Rooster Kat.'  → 298 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2019_Q4 2019 Red Rooster.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 54 rows  Net Amount='Nettoumsatz Vormonat'
#   T  2019_Q4 2019 Red Rooster.xlsx / 'digital GSA Red Rooster Katalog'  → 16,239 rows
#   T  2019_Q4 2019 Red Rooster.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 854 rows
# [9/41] 2020 _Red Rooster Q3 2020.xlsx
#   R  2020 _Red Rooster Q3 2020.xlsx / 'physisch GSA Red Rooster Kat.'  → 276 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2020 _Red Rooster Q3 2020.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 48 rows  Net Amount='Nettoumsatz Vormonat'
#   T  2020 _Red Rooster Q3 2020.xlsx / 'digital GSA Red Rooster Katalog'  → 9,545 rows
#   T  2020 _Red Rooster Q3 2020.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 870 rows
# [10/41] 2020_Red Rooster Q1 2020.xlsx
#   R  2020_Red Rooster Q1 2020.xlsx / 'physisch GSA Red Rooster Kat.'  → 298 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2020_Red Rooster Q1 2020.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 57 rows  Net Amount='Nettoumsatz Vormonat'
#   T  2020_Red Rooster Q1 2020.xlsx / 'digital GSA Red Rooster Katalog'  → 7,403 rows
#   T  2020_Red Rooster Q1 2020.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 618 rows
# [11/41] 2020_Red Rooster Q2 2020.xlsx
#   R  2020_Red Rooster Q2 2020.xlsx / 'physisch GSA Red Rooster Kat.'  → 286 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2020_Red Rooster Q2 2020.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 30 rows  Net Amount='Nettoumsatz Vormonat'
#   T  2020_Red Rooster Q2 2020.xlsx / 'digital GSA Red Rooster Katalog'  → 21,874 rows
#   T  2020_Red Rooster Q2 2020.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 1,319 rows
# [12/41] 2020_komplett  Red Rooster Maffay Q4 2020.xlsx
#   R  2020_komplett  Red Rooster Maffay Q4 2020.xlsx / 'physisch GSA Red Rooster Kat.'  → 296 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2020_komplett  Red Rooster Maffay Q4 2020.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 37 rows  Net Amount='Nettoumsatz Vormonat'
#   P  2020_komplett  Red Rooster Maffay Q4 2020.xlsx / 'digital GSA Red Rooster Katalog'  → 99,412 rows
#   P  2020_komplett  Red Rooster Maffay Q4 2020.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 11,277 rows
# [13/41] 2021_Q1 2021  Red Rooster Q1 2021.xlsx
#   R  2021_Q1 2021  Red Rooster Q1 2021.xlsx / 'physisch GSA Red Rooster Kat.'  → 296 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2021_Q1 2021  Red Rooster Q1 2021.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 40 rows  Net Amount='Nettoumsatz Vormonat'
#   P  2021_Q1 2021  Red Rooster Q1 2021.xlsx / 'digital GSA Red Rooster Katalog'  → 45,204 rows
#   P  2021_Q1 2021  Red Rooster Q1 2021.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 7,452 rows
# [14/41] 2021_Q2 2021 Red Rooster Q2 2021.xlsx
#   R  2021_Q2 2021 Red Rooster Q2 2021.xlsx / 'physisch GSA Red Rooster Kat.'  → 247 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2021_Q2 2021 Red Rooster Q2 2021.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 37 rows  Net Amount='Nettoumsatz Vormonat'
#   P  2021_Q2 2021 Red Rooster Q2 2021.xlsx / 'digital GSA Red Rooster Katalog'  → 116,399 rows
#   P  2021_Q2 2021 Red Rooster Q2 2021.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 13,329 rows
# [15/41] 2021_Q3 2021 Red Rooster.xlsx
#   R  2021_Q3 2021 Red Rooster.xlsx / 'physisch GSA Red Rooster Kat.'  → 283 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2021_Q3 2021 Red Rooster.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 31 rows  Net Amount='Nettoumsatz Vormonat'
#   P  2021_Q3 2021 Red Rooster.xlsx / 'digital GSA Red Rooster Katalog'  → 52,149 rows
#   P  2021_Q3 2021 Red Rooster.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 7,557 rows
# [16/41] 2021_Q4 2021 Red Rooster Q4 2021.xlsx
#   R  2021_Q4 2021 Red Rooster Q4 2021.xlsx / 'physisch GSA Red Rooster Kat.'  → 264 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2021_Q4 2021 Red Rooster Q4 2021.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 43 rows  Net Amount='Nettoumsatz Vormonat'
#   P  2021_Q4 2021 Red Rooster Q4 2021.xlsx / 'digital GSA Red Rooster Katalog'  → 106,303 rows
#   P  2021_Q4 2021 Red Rooster Q4 2021.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 10,866 rows
#   Q  2021_Q4 2021 Red Rooster Q4 2021.xlsx / 'dig.Ex-GSA Katalog'  → 91,786 rows
#   Q  2021_Q4 2021 Red Rooster Q4 2021.xlsx / 'dig.Ex-GSA MTV'  → 11,100 rows
#   Q  2021_Q4 2021 Red Rooster Q4 2021.xlsx / 'other income_GVL Katalog'  → 9,251 rows
#   Q  2021_Q4 2021 Red Rooster Q4 2021.xlsx / 'other income_GVL MTV'  → 955 rows
#   Q  2021_Q4 2021 Red Rooster Q4 2021.xlsx / 'Kopplungserlöse Katalog'  → 24 rows
# [17/41] 2022_Q1_2022_Red Rooster Q1 2022.xlsx
#   R  2022_Q1_2022_Red Rooster Q1 2022.xlsx / 'physisch GSA Red Rooster Kat.'  → 249 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2022_Q1_2022_Red Rooster Q1 2022.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 32 rows  Net Amount='Nettoumsatz Vormonat'
#   P  2022_Q1_2022_Red Rooster Q1 2022.xlsx / 'digital GSA Red Rooster Katalog'  → 39,595 rows
#   P  2022_Q1_2022_Red Rooster Q1 2022.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 5,990 rows
#   Q  2022_Q1_2022_Red Rooster Q1 2022.xlsx / 'dig.Ex-GSA Katalog'  → 10,795 rows
#   Q  2022_Q1_2022_Red Rooster Q1 2022.xlsx / 'dig.Ex-GSA MTV'  → 1,819 rows
#   Q  2022_Q1_2022_Red Rooster Q1 2022.xlsx / 'Kopplungserlöse Katalog'  → 71 rows
# [18/41] 2022_Q2_2022 Abrechnung Red Rooster.xlsx
#   R  2022_Q2_2022 Abrechnung Red Rooster.xlsx / 'physisch GSA Red Rooster Kat.'  → 238 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2022_Q2_2022 Abrechnung Red Rooster.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 36 rows  Net Amount='Nettoumsatz Vormonat'
#   P  2022_Q2_2022 Abrechnung Red Rooster.xlsx / 'digital GSA Red Rooster Katalog'  → 118,311 rows
#   P  2022_Q2_2022 Abrechnung Red Rooster.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 12,153 rows
#   Q  2022_Q2_2022 Abrechnung Red Rooster.xlsx / 'dig.Ex-GSA Katalog'  → 132,960 rows
#   Q  2022_Q2_2022 Abrechnung Red Rooster.xlsx / 'dig.Ex-GSA MTV'  → 13,441 rows
#   Q  2022_Q2_2022 Abrechnung Red Rooster.xlsx / 'Kopplungserlöse Katalog'  → 68 rows
# [19/41] 2022_Q3_2022_Red Rooster Q3 2022 Abrechnung.xlsx
#   R  2022_Q3_2022_Red Rooster Q3 2022 Abrechnung.xlsx / 'physisch GSA Red Rooster Kat.'  → 247 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2022_Q3_2022_Red Rooster Q3 2022 Abrechnung.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 36 rows  Net Amount='Nettoumsatz Vormonat'
#   P  2022_Q3_2022_Red Rooster Q3 2022 Abrechnung.xlsx / 'digital GSA Red Rooster Katalog'  → 79,961 rows
#   P  2022_Q3_2022_Red Rooster Q3 2022 Abrechnung.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 11,752 rows
#   Q  2022_Q3_2022_Red Rooster Q3 2022 Abrechnung.xlsx / 'dig.Ex-GSA Katalog'  → 9,728 rows
#   Q  2022_Q3_2022_Red Rooster Q3 2022 Abrechnung.xlsx / 'dig.Ex-GSA MTV'  → 2,173 rows
#   Q  2022_Q3_2022_Red Rooster Q3 2022 Abrechnung.xlsx / 'Kopplungserlöse MTV'  → 13 rows
#   Q  2022_Q3_2022_Red Rooster Q3 2022 Abrechnung.xlsx / 'Kopplungserlöse Katalog'  → 24 rows
# [20/41] 2022_Q4_2022 Red Rooster Q4 2022 Abrechnung.xlsx
#   R  2022_Q4_2022 Red Rooster Q4 2022 Abrechnung.xlsx / 'physisch GSA Red Rooster Kat.'  → 263 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2022_Q4_2022 Red Rooster Q4 2022 Abrechnung.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 37 rows  Net Amount='Nettoumsatz Vormonat'
#   P  2022_Q4_2022 Red Rooster Q4 2022 Abrechnung.xlsx / 'digital GSA Red Rooster Katalog'  → 32,387 rows
#   P  2022_Q4_2022 Red Rooster Q4 2022 Abrechnung.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 4,698 rows
#   Q  2022_Q4_2022 Red Rooster Q4 2022 Abrechnung.xlsx / 'dig.Ex-GSA Katalog'  → 89,306 rows
#   Q  2022_Q4_2022 Red Rooster Q4 2022 Abrechnung.xlsx / 'dig.Ex-GSA MTV'  → 8,466 rows
#   Q  2022_Q4_2022 Red Rooster Q4 2022 Abrechnung.xlsx / 'other income_GVL Katalog'  → 13,965 rows
#   Q  2022_Q4_2022 Red Rooster Q4 2022 Abrechnung.xlsx / 'Kopplungserlöse MTV'  → 1 rows
#   Q  2022_Q4_2022 Red Rooster Q4 2022 Abrechnung.xlsx / 'other income_GVL MTV'  → 826 rows
#   Q  2022_Q4_2022 Red Rooster Q4 2022 Abrechnung.xlsx / 'Kopplungserlöse Katalog'  → 48 rows
# [21/41] 2023-Q1 Red Rooster Q1 2023 Abrechnung 1.xlsx
#   R  2023-Q1 Red Rooster Q1 2023 Abrechnung 1.xlsx / 'physisch GSA Red Rooster Kat.'  → 336 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2023-Q1 Red Rooster Q1 2023 Abrechnung 1.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 38 rows  Net Amount='Nettoumsatz Vormonat'
#   P  2023-Q1 Red Rooster Q1 2023 Abrechnung 1.xlsx / 'digital GSA Red Rooster Katalog'  → 167,348 rows
#   P  2023-Q1 Red Rooster Q1 2023 Abrechnung 1.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 13,517 rows
#   Q  2023-Q1 Red Rooster Q1 2023 Abrechnung 1.xlsx / 'dig.Ex-GSA Katalog'  → 103,207 rows
#   Q  2023-Q1 Red Rooster Q1 2023 Abrechnung 1.xlsx / 'dig.Ex-GSA MTV'  → 11,168 rows
#   Q  2023-Q1 Red Rooster Q1 2023 Abrechnung 1.xlsx / 'other income_GVL Katalog'  → 3,330 rows
#   Q  2023-Q1 Red Rooster Q1 2023 Abrechnung 1.xlsx / 'other income_GVL MTV'  → 217 rows
#   Q  2023-Q1 Red Rooster Q1 2023 Abrechnung 1.xlsx / 'Kopplungserlöse Katalog'  → 20 rows
# [22/41] 2023-Q2 Red Rooster Abrechnung.xlsx
#   R  2023-Q2 Red Rooster Abrechnung.xlsx / 'physisch GSA Red Rooster Kat.'  → 269 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2023-Q2 Red Rooster Abrechnung.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 33 rows  Net Amount='Nettoumsatz Vormonat'
#   P  2023-Q2 Red Rooster Abrechnung.xlsx / 'digital GSA Red Rooster Katalog'  → 192,988 rows
#   P  2023-Q2 Red Rooster Abrechnung.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 14,429 rows
#   Q  2023-Q2 Red Rooster Abrechnung.xlsx / 'dig.Ex-GSA Katalog'  → 47,479 rows
#   Q  2023-Q2 Red Rooster Abrechnung.xlsx / 'dig.Ex-GSA MTV'  → 4,987 rows
#   Q  2023-Q2 Red Rooster Abrechnung.xlsx / 'other income_GVL Katalog'  → 8,176 rows
#   Q  2023-Q2 Red Rooster Abrechnung.xlsx / 'other income_GVL MTV'  → 568 rows
#   Q  2023-Q2 Red Rooster Abrechnung.xlsx / 'Kopplungserlöse Katalog'  → 19 rows
# [23/41] 2023-Q3 Red Rooster Q3 2023 Abrechnung.xlsx
#   R  2023-Q3 Red Rooster Q3 2023 Abrechnung.xlsx / 'physisch GSA Red Rooster Kat.'  → 224 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2023-Q3 Red Rooster Q3 2023 Abrechnung.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 25 rows  Net Amount='Nettoumsatz Vormonat'
#   P  2023-Q3 Red Rooster Q3 2023 Abrechnung.xlsx / 'digital GSA Red Rooster Katalog'  → 44,037 rows
#   P  2023-Q3 Red Rooster Q3 2023 Abrechnung.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 5,020 rows
#   Q  2023-Q3 Red Rooster Q3 2023 Abrechnung.xlsx / 'dig.Ex-GSA Katalog'  → 85,903 rows
#   Q  2023-Q3 Red Rooster Q3 2023 Abrechnung.xlsx / 'dig.Ex-GSA MTV'  → 9,371 rows
#   Q  2023-Q3 Red Rooster Q3 2023 Abrechnung.xlsx / 'other income_GVL Katalog'  → 2,274 rows
#   Q  2023-Q3 Red Rooster Q3 2023 Abrechnung.xlsx / 'other income_GVL MTV'  → 105 rows
#   Q  2023-Q3 Red Rooster Q3 2023 Abrechnung.xlsx / 'Kopplungserlöse Katalog'  → 18 rows
# [24/41] 2023-Q4 Red Rooster Q4 2023 Abrechnung x.xlsx
#   R  2023-Q4 Red Rooster Q4 2023 Abrechnung x.xlsx / 'physisch GSA Red Rooster Kat.'  → 221 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2023-Q4 Red Rooster Q4 2023 Abrechnung x.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 26 rows  Net Amount='Nettoumsatz Vormonat'
#   P  2023-Q4 Red Rooster Q4 2023 Abrechnung x.xlsx / 'digital GSA Red Rooster Katalog'  → 148,788 rows
#   P  2023-Q4 Red Rooster Q4 2023 Abrechnung x.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 11,399 rows
#   Q  2023-Q4 Red Rooster Q4 2023 Abrechnung x.xlsx / 'dig.Ex-GSA Katalog'  → 6,623 rows
#   Q  2023-Q4 Red Rooster Q4 2023 Abrechnung x.xlsx / 'dig.Ex-GSA MTV'  → 891 rows
#   Q  2023-Q4 Red Rooster Q4 2023 Abrechnung x.xlsx / 'other income_GVL Katalog'  → 1,326 rows
#   Q  2023-Q4 Red Rooster Q4 2023 Abrechnung x.xlsx / 'other income_GVL MTV'  → 128 rows
#   Q  2023-Q4 Red Rooster Q4 2023 Abrechnung x.xlsx / 'Kopplungserlöse Katalog'  → 20 rows
# [25/41] 2024_Q1_Red Rooster Q1 2024 Abrechnung.xlsx
#   R  2024_Q1_Red Rooster Q1 2024 Abrechnung.xlsx / 'physisch GSA Red Rooster Kat.'  → 232 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2024_Q1_Red Rooster Q1 2024 Abrechnung.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 27 rows  Net Amount='Nettoumsatz Vormonat'
#   P  2024_Q1_Red Rooster Q1 2024 Abrechnung.xlsx / 'digital GSA Red Rooster Katalog'  → 79,865 rows
#   P  2024_Q1_Red Rooster Q1 2024 Abrechnung.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 7,994 rows
#   Q  2024_Q1_Red Rooster Q1 2024 Abrechnung.xlsx / 'dig.Ex-GSA Katalog'  → 123,548 rows
#   Q  2024_Q1_Red Rooster Q1 2024 Abrechnung.xlsx / 'dig.Ex-GSA MTV'  → 14,608 rows
#   Q  2024_Q1_Red Rooster Q1 2024 Abrechnung.xlsx / 'other income_GVL Katalog'  → 2,235 rows
#   Q  2024_Q1_Red Rooster Q1 2024 Abrechnung.xlsx / 'other income_GVL MTV'  → 205 rows
#   Q  2024_Q1_Red Rooster Q1 2024 Abrechnung.xlsx / 'Kopplungserlöse Katalog'  → 11 rows
# [26/41] 2024_Q2_Red Rooster Q2 2024 Abrechnung.xlsx
#   R  2024_Q2_Red Rooster Q2 2024 Abrechnung.xlsx / 'physisch GSA Red Rooster Kat.'  → 187 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2024_Q2_Red Rooster Q2 2024 Abrechnung.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 24 rows  Net Amount='Nettoumsatz Vormonat'
#   P  2024_Q2_Red Rooster Q2 2024 Abrechnung.xlsx / 'digital GSA Red Rooster Katalog'  → 241,678 rows
#   P  2024_Q2_Red Rooster Q2 2024 Abrechnung.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 19,159 rows
#   Q  2024_Q2_Red Rooster Q2 2024 Abrechnung.xlsx / 'dig.Ex-GSA Katalog'  → 41,249 rows
#   Q  2024_Q2_Red Rooster Q2 2024 Abrechnung.xlsx / 'dig.Ex-GSA MTV'  → 4,170 rows
#   Q  2024_Q2_Red Rooster Q2 2024 Abrechnung.xlsx / 'other income_GVL Katalog'  → 11,554 rows
#   Q  2024_Q2_Red Rooster Q2 2024 Abrechnung.xlsx / 'other income_GVL MTV'  → 963 rows
#   Q  2024_Q2_Red Rooster Q2 2024 Abrechnung.xlsx / 'Kopplungserlöse Katalog'  → 12 rows
# [27/41] 2024_Q3_Red Rooster Q3 2024 Abrechnung.xlsx
#   R  2024_Q3_Red Rooster Q3 2024 Abrechnung.xlsx / 'physisch GSA Red Rooster Kat.'  → 186 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2024_Q3_Red Rooster Q3 2024 Abrechnung.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 26 rows  Net Amount='Nettoumsatz Vormonat'
#   P  2024_Q3_Red Rooster Q3 2024 Abrechnung.xlsx / 'digital GSA Red Rooster Katalog'  → 93,597 rows
#   P  2024_Q3_Red Rooster Q3 2024 Abrechnung.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 8,448 rows
#   Q  2024_Q3_Red Rooster Q3 2024 Abrechnung.xlsx / 'dig.Ex-GSA Katalog'  → 17,488 rows
#   Q  2024_Q3_Red Rooster Q3 2024 Abrechnung.xlsx / 'dig.Ex-GSA MTV'  → 1,645 rows
#   Q  2024_Q3_Red Rooster Q3 2024 Abrechnung.xlsx / 'other income_GVL Katalog'  → 8,322 rows
#   Q  2024_Q3_Red Rooster Q3 2024 Abrechnung.xlsx / 'other income_GVL MTV'  → 620 rows
#   Q  2024_Q3_Red Rooster Q3 2024 Abrechnung.xlsx / 'Kopplungserlöse Katalog'  → 13 rows
# [28/41] 2024_Q4_Red Rooster Q4 2024 Abrechnung.xlsx
#   R  2024_Q4_Red Rooster Q4 2024 Abrechnung.xlsx / 'physisch GSA Red Rooster Kat.'  → 267 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2024_Q4_Red Rooster Q4 2024 Abrechnung.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 53 rows  Net Amount='Nettoumsatz Vormonat'
#   P  2024_Q4_Red Rooster Q4 2024 Abrechnung.xlsx / 'digital GSA Red Rooster Katalog'  → 64,158 rows
#   P  2024_Q4_Red Rooster Q4 2024 Abrechnung.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 5,095 rows
#   Q  2024_Q4_Red Rooster Q4 2024 Abrechnung.xlsx / 'dig.Ex-GSA Katalog'  → 44,680 rows
#   Q  2024_Q4_Red Rooster Q4 2024 Abrechnung.xlsx / 'dig.Ex-GSA MTV'  → 4,907 rows
#   Q  2024_Q4_Red Rooster Q4 2024 Abrechnung.xlsx / 'other income_GVL Katalog'  → 9,561 rows
#   Q  2024_Q4_Red Rooster Q4 2024 Abrechnung.xlsx / 'other income_GVL MTV'  → 332 rows
#   Q  2024_Q4_Red Rooster Q4 2024 Abrechnung.xlsx / 'Kopplungserlöse Katalog'  → 11 rows
# [29/41] 2025_Red Rooster Q1 2025 Abrechnung.xlsx
#   P  2025_Red Rooster Q1 2025 Abrechnung.xlsx / 'Anouk - Das Musical Q4 2024'  → 233 rows
#   R  2025_Red Rooster Q1 2025 Abrechnung.xlsx / 'physisch GSA Red Rooster Kat.'  → 212 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2025_Red Rooster Q1 2025 Abrechnung.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 20 rows  Net Amount='Nettoumsatz Vormonat'
#   P  2025_Red Rooster Q1 2025 Abrechnung.xlsx / 'digital GSA Red Rooster Katalog'  → 98,497 rows
#   P  2025_Red Rooster Q1 2025 Abrechnung.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 7,254 rows
#   Q  2025_Red Rooster Q1 2025 Abrechnung.xlsx / 'dig.Ex-GSA Katalog'  → 74,097 rows
#   Q  2025_Red Rooster Q1 2025 Abrechnung.xlsx / 'dig.Ex-GSA MTV'  → 6,044 rows
#   Q  2025_Red Rooster Q1 2025 Abrechnung.xlsx / 'other income_GVL Katalog'  → 11,642 rows
#   Q  2025_Red Rooster Q1 2025 Abrechnung.xlsx / 'other income_GVL MTV'  → 769 rows
#   Q  2025_Red Rooster Q1 2025 Abrechnung.xlsx / 'Kopplungserlöse Katalog'  → 14 rows
# [30/41] 2025_Red Rooster Q2 2025 Abrechnung.xlsx
#   R  2025_Red Rooster Q2 2025 Abrechnung.xlsx / 'physisch GSA Red Rooster Kat.'  → 172 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2025_Red Rooster Q2 2025 Abrechnung.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 20 rows  Net Amount='Nettoumsatz Vormonat'
#   P  2025_Red Rooster Q2 2025 Abrechnung.xlsx / 'digital GSA Red Rooster Katalog'  → 65,790 rows
#   P  2025_Red Rooster Q2 2025 Abrechnung.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 6,109 rows
#   Q  2025_Red Rooster Q2 2025 Abrechnung.xlsx / 'dig.Ex-GSA Katalog'  → 49,982 rows
#   Q  2025_Red Rooster Q2 2025 Abrechnung.xlsx / 'dig.Ex-GSA MTV'  → 1,849 rows
#   Q  2025_Red Rooster Q2 2025 Abrechnung.xlsx / 'other income_GVL Katalog'  → 7,148 rows
#   Q  2025_Red Rooster Q2 2025 Abrechnung.xlsx / 'other income_GVL MTV'  → 386 rows
#   Q  2025_Red Rooster Q2 2025 Abrechnung.xlsx / 'Kopplungserlöse Katalog'  → 13 rows
# [31/41] 2025_Red Rooster Q3 2025 Abrechnung.xlsx
#   R  2025_Red Rooster Q3 2025 Abrechnung.xlsx / 'physisch GSA Red Rooster Kat.'  → 162 rows  Net Amount='Nettoumsatz Vormonat'
#   R  2025_Red Rooster Q3 2025 Abrechnung.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 20 rows  Net Amount='Nettoumsatz Vormonat'
#   P  2025_Red Rooster Q3 2025 Abrechnung.xlsx / 'digital GSA Red Rooster Katalog'  → 123,638 rows
#   P  2025_Red Rooster Q3 2025 Abrechnung.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 8,836 rows
#   Q  2025_Red Rooster Q3 2025 Abrechnung.xlsx / 'dig.Ex-GSA Katalog'  → 96,008 rows
#   Q  2025_Red Rooster Q3 2025 Abrechnung.xlsx / 'dig.Ex-GSA MTV'  → 11,466 rows
#   Q  2025_Red Rooster Q3 2025 Abrechnung.xlsx / 'other income_GVL Katalog'  → 5,917 rows
#   Q  2025_Red Rooster Q3 2025 Abrechnung.xlsx / 'other income_GVL MTV'  → 342 rows
#   Q  2025_Red Rooster Q3 2025 Abrechnung.xlsx / 'Kopplungserlöse Katalog'  → 12 rows
# [32/41] 2025_Red Rooster Q4 2025 Abrechnung.xlsx
#   S  2025_Red Rooster Q4 2025 Abrechnung.xlsx / 'physisch GSA Red Rooster Kat.'  → 177 rows  Net Amount='Nettoumsatz Vormonat'
#   S  2025_Red Rooster Q4 2025 Abrechnung.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 18 rows  Net Amount='Nettoumsatz Vormonat'
#   P  2025_Red Rooster Q4 2025 Abrechnung.xlsx / 'digital GSA Red Rooster Katalog'  → 44,557 rows
#   P  2025_Red Rooster Q4 2025 Abrechnung.xlsx / 'dig.GSA Red Rooster MTV Unpl.'  → 4,212 rows
#   Q  2025_Red Rooster Q4 2025 Abrechnung.xlsx / 'dig.Ex-GSA Katalog'  → 7,934 rows
#   Q  2025_Red Rooster Q4 2025 Abrechnung.xlsx / 'dig.Ex-GSA MTV'  → 529 rows
#   Q  2025_Red Rooster Q4 2025 Abrechnung.xlsx / 'other income_GVL Katalog'  → 1,705 rows
#   Q  2025_Red Rooster Q4 2025 Abrechnung.xlsx / 'other income_GVL MTV'  → 82 rows
#   Q  2025_Red Rooster Q4 2025 Abrechnung.xlsx / 'Kopplungserlöse Katalog'  → 6 rows
# [33/41] Q4 2017 Red Rooster Digital.xls
#   SKIP file (cannot open): Q4 2017 Red Rooster Digital.xls — Reading Q4 2017 .xls files needs xlrd. Install with: pip install xlrd
# [34/41] Q4 2017 Red Rooster MTV Unplugged Digital.xls
#   SKIP file (cannot open): Q4 2017 Red Rooster MTV Unplugged Digital.xls — Reading Q4 2017 .xls files needs xlrd. Install with: pip install xlrd
# [35/41] Q4 2017 Red Rooster Physical A.xls
#   SKIP file (cannot open): Q4 2017 Red Rooster Physical A.xls — Reading Q4 2017 .xls files needs xlrd. Install with: pip install xlrd
# [36/41] Q4 2017 Red Rooster Physical CH.xls
#   SKIP file (cannot open): Q4 2017 Red Rooster Physical CH.xls — Reading Q4 2017 .xls files needs xlrd. Install with: pip install xlrd
# [37/41] Q4 2017 Red Rooster Physical D.xls
#   SKIP file (cannot open): Q4 2017 Red Rooster Physical D.xls — Reading Q4 2017 .xls files needs xlrd. Install with: pip install xlrd
# [38/41] Q4 2017 Red Rooster Physical MTV Unplugged A.xls
#   SKIP file (cannot open): Q4 2017 Red Rooster Physical MTV Unplugged A.xls — Reading Q4 2017 .xls files needs xlrd. Install with: pip install xlrd
# [39/41] Q4 2017 Red Rooster Physical MTV Unplugged CH.xls
#   SKIP file (cannot open): Q4 2017 Red Rooster Physical MTV Unplugged CH.xls — Reading Q4 2017 .xls files needs xlrd. Install with: pip install xlrd
# [40/41] Q4 2017 Red Rooster Physical MTV Unplugged D.xls
#   SKIP file (cannot open): Q4 2017 Red Rooster Physical MTV Unplugged D.xls — Reading Q4 2017 .xls files needs xlrd. Install with: pip install xlrd
# [41/41] Red Rooster Q1 2026 Abrechnung.xlsx
#   S  Red Rooster Q1 2026 Abrechnung.xlsx / 'physisch GSA Red Rooster Kat.'  → 166 rows  Net Amount='Nettoumsatz Vormonat'
#   S  Red Rooster Q1 2026 Abrechnung.xlsx / 'phys.GSA Red Rooster MTV Unpl.'  → 20 rows  Net Amount='Nettoumsatz Vormonat'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 40
#      38 for i, path in enumerate(files, 1):
#      39     print(f"[{i}/{len(files)}] {path.name}")
# ---> 40     all_frames.extend(process_workbook(path))
#      42 if not all_frames:
#      43     raise RuntimeError("No sheets were mapped. Check as-received files and skip rules.")
#
# Cell In[47], line 453, in process_workbook(path)
#     451     continue
#     452 try:
# --> 453     df = load_sheet(path, sheet)
#     454 except Exception as exc:
#     455     print(f"  SKIP sheet {path.name} / {sheet!r}: {exc}")
#
# Cell In[47], line 429, in load_sheet(path, sheet)
#     427     df = read_xls_sheet(path, sheet)
#     428 else:
# --> 429     df = pd.read_excel(path, sheet_name=sheet)
#     430 if df.empty:
#     431     return df
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/excel/_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#     507 try:
# --> 508     data = io.parse(
#     509         sheet_name=sheet_name,
#     510         header=header,
#     511         names=names,
#     512         index_col=index_col,
#     513         usecols=usecols,
#     514         dtype=dtype,
#     515         converters=converters,
#     516         true_values=true_values,
#     517         false_values=false_values,
#     518         skiprows=skiprows,
#     519         nrows=nrows,
#     520         na_values=na_values,
#     521         keep_default_na=keep_default_na,
#     522         na_filter=na_filter,
#     523         verbose=verbose,
#     524         parse_dates=parse_dates,
#     525         date_parser=date_parser,
#     526         date_format=date_format,
#     527         thousands=thousands,
#     528         decimal=decimal,
#     529         comment=comment,
#     530         skipfooter=skipfooter,
#     531         dtype_backend=dtype_backend,
#     532     )
#     533 finally:
#     534     # make sure to close opened file handles
#     535     if should_close:
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/excel/_base.py:1616, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, date_format, thousands, comment, skipfooter, dtype_backend, **kwds)
#    1576 def parse(
#    1577     self,
#    1578     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)
#    1596     **kwds,
#    1597 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1598     """
#    1599     Parse specified sheet(s) into a DataFrame.
#    1600
#    (...)
#    1614     >>> file.parse()  # doctest: +SKIP
#    1615     """
# -> 1616     return self._reader.parse(
#    1617         sheet_name=sheet_name,
#    1618         header=header,
#    1619         names=names,
#    1620         index_col=index_col,
#    1621         usecols=usecols,
#    1622         converters=converters,
#    1623         true_values=true_values,
#    1624         false_values=false_values,
#    1625         skiprows=skiprows,
#    1626         nrows=nrows,
#    1627         na_values=na_values,
#    1628         parse_dates=parse_dates,
#    1629         date_parser=date_parser,
#    1630         date_format=date_format,
#    1631         thousands=thousands,
#    1632         comment=comment,
#    1633         skipfooter=skipfooter,
#    1634         dtype_backend=dtype_backend,
#    1635         **kwds,
#    1636     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/excel/_base.py:778, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, dtype_backend, **kwds)
#     775     sheet = self.get_sheet_by_index(asheetname)
#     777 file_rows_needed = self._calc_rows(header, index_col, skiprows, nrows)
# --> 778 data = self.get_sheet_data(sheet, file_rows_needed)
#     779 if hasattr(sheet, "close"):
#     780     # pyxlsb opens two TemporaryFiles
#     781     sheet.close()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/excel/_openpyxl.py:615, in OpenpyxlReader.get_sheet_data(self, sheet, file_rows_needed)
#     613 data: list[list[Scalar]] = []
#     614 last_row_with_data = -1
# --> 615 for row_number, row in enumerate(sheet.rows):
#     616     converted_row = [self._convert_cell(cell) for cell in row]
#     617     while converted_row and converted_row[-1] == "":
#     618         # trim trailing empty elements
#
# File /opt/anaconda3/lib/python3.12/site-packages/openpyxl/worksheet/_read_only.py:81, in ReadOnlyWorksheet._cells_by_row(self, min_col, min_row, max_col, max_row, values_only)
#      77 src = self._get_source()
#      78 parser = WorkSheetParser(src, self._shared_strings,
#      79                          data_only=self.parent.data_only, epoch=self.parent.epoch,
#      80                          date_formats=self.parent._date_formats)
# ---> 81 for idx, row in parser.parse():
#      82     if max_row is not None and idx > max_row:
#      83         break
#
# File /opt/anaconda3/lib/python3.12/site-packages/openpyxl/worksheet/_reader.py:156, in parse()
#
# File /opt/anaconda3/lib/python3.12/xml/etree/ElementTree.py:1241, in iterparse.<locals>.iterator(source)
#    1239     if not data:
#    1240         break
# -> 1241     pullparser.feed(data)
#    1242 root = pullparser._close_and_return_root()
#    1243 yield from pullparser.read_events()
#
# File /opt/anaconda3/lib/python3.12/xml/etree/ElementTree.py:1284, in XMLPullParser.feed(self, data)
#    1282 if data:
#    1283     try:
# -> 1284         self._parser.feed(data)
#    1285     except SyntaxError as exc:
#    1286         self._events_queue.append(exc)
#
# File /opt/anaconda3/lib/python3.12/xml/etree/ElementTree.py:1706, in XMLParser.feed(self, data)
#    1704 """Feed encoded data to parser."""
#    1705 try:
# -> 1706     self.parser.Parse(data, False)
#    1707 except self._error as v:
#    1708     self._raiseerror(v)
#
# File /var/folders/k1/30mswbxs7r1g6zwn8y4fyt500000gp/T/abs_a4d6bjwrp2/croot/python-split_1718722877824/work/Modules/pyexpat.c:423, in StartElement()
#
# File /opt/anaconda3/lib/python3.12/xml/etree/ElementTree.py:1634, in XMLParser._start(self, tag, attr_list)
#    1631 def _end_ns(self, prefix):
#    1632     return self.target.end_ns(prefix or '')
# -> 1634 def _start(self, tag, attr_list):
#    1635     # Handler for expat's StartElementHandler. Since ordered_attributes
#    1636     # is set, the attributes are reported as a list of alternating
#    1637     # attribute name,value.
#    1638     fixname = self._fixname
#    1639     tag = fixname(tag)
#
# KeyboardInterrupt:

# %%
if globals().get("LOADED_FROM_CSV"):
    print("Loaded from combined CSV; skipping harmonise.")
else:
    CODE_SUFFIX = re.compile(r"\s*\([A-Za-z]\|[A-Za-z0-9]+\|?\s*\)\s*$")
    CODE_INSIDE = re.compile(r"\(\s*([A-Za-z])\|([A-Za-z0-9]+)\|?\s*\)")


    def normalise_key(value):
        return re.sub(r"\s+", " ", str(value).strip()).casefold()


    def key_variants(value):
        """Match DSP/title keys across minor source-format differences."""
        raw = re.sub(r"\s+", " ", str(value).strip())
        variants = [raw, CODE_INSIDE.sub(r"(\1|\2| )", raw), CODE_INSIDE.sub(r"(\1|\2)", raw)]
        stripped = CODE_SUFFIX.sub("", raw).strip()
        if stripped and stripped != raw:
            variants.append(stripped)
        seen = set()
        out = []
        for variant in variants:
            key = normalise_key(variant)
            if key and key not in seen:
                seen.add(key)
                out.append(key)
        return out


    def build_lookup(lookup_map):
        normalised = {}
        for key, value in lookup_map.items():
            if pd.isna(key):
                continue
            for variant in key_variants(key):
                normalised.setdefault(variant, value)
        return normalised


    def harmonise(df, column, new_column, lookup_map, label, warn=True):
        normalised_lookup = build_lookup(lookup_map)

        def map_one(value):
            if pd.isna(value):
                return pd.NA
            for variant in key_variants(value):
                if variant in normalised_lookup:
                    return normalised_lookup[variant]
            return pd.NA

        mapped = df[column].map(map_one)
        missing_mask = df[column].notna() & mapped.isna()
        if warn and missing_mask.any():
            counts = df.loc[missing_mask, column].value_counts()
            print(
                f"WARNING: {len(counts)} '{column}' value(s) could not be harmonised "
                f"against {label} ({missing_mask.sum():,} rows):"
            )
            for value, count in counts.head(40).items():
                print(f"  {value!r} ({count:,} rows)")
            if len(counts) > 40:
                print(f"  … {len(counts) - 40} more")
            print()
        df[new_column] = mapped
        return df


    title_lookup_df = pd.read_excel(lookup_dir / "Title.xlsx")
    title_lookup = dict(zip(title_lookup_df["Product Title"], title_lookup_df["Product Title (harmonised)"]))
    dsp_lookup_df = pd.read_excel(lookup_dir / "DSP.xlsx")
    dsp_lookup = dict(zip(dsp_lookup_df["Third Party / DSP"], dsp_lookup_df["Third Party / DSP (Group)"]))
    country_lookup_df = pd.read_excel(lookup_dir / "Country.xlsx")
    country_lookup = dict(zip(country_lookup_df["Country of Sale"], country_lookup_df["Country of Sale (harmonised)"]))
    gsa_lookup = dict(zip(country_lookup_df["Country of Sale"], country_lookup_df["GSA"]))
    income_type_lookup_df = pd.read_excel(lookup_dir / "Income_type.xlsx")
    income_type_lookup = dict(zip(income_type_lookup_df["Tab Name"], income_type_lookup_df["Type of income"]))
    source_lookup_df = pd.read_excel(lookup_dir / "Source.xlsx")
    source_lookup = dict(zip(source_lookup_df["Tab Name"], source_lookup_df["Source"]))

    combined = harmonise(combined, "Product Title", "Product Title (harmonised)", title_lookup, "Title.xlsx")
    combined = harmonise(combined, "Third Party / DSP", "Third Party / DSP (Group)", dsp_lookup, "DSP.xlsx")
    combined = harmonise(combined, "Country of Sale", "Country of Sale (harmonised)", country_lookup, "Country.xlsx")
    combined = harmonise(combined, "Country of Sale", "GSA", gsa_lookup, "Country.xlsx", warn=False)
    combined = harmonise(combined, "Tab Name", "Type of income", income_type_lookup, "Income_type.xlsx")
    combined = harmonise(combined, "Tab Name", "Source", source_lookup, "Source.xlsx")

    final_columns = []
    for column in CANONICAL:
        final_columns.append(column)
        if column == "Tab Name":
            final_columns.append("Type of income")
            final_columns.append("Source")
        if column == "Product Title":
            final_columns.append("Product Title (harmonised)")
        if column == "Third Party / DSP":
            final_columns.append("Third Party / DSP (Group)")
        if column == "Country of Sale":
            final_columns.append("Country of Sale (harmonised)")
            final_columns.append("GSA")
    final_columns.append("Source Group")
    combined = combined.reindex(columns=final_columns)
    combined.head(3)
# Out:
# Loaded from combined CSV; skipping harmonise.

# %%
if globals().get("LOADED_FROM_CSV"):
    print("Loaded from combined CSV; not rewriting the main CSV.")
else:
    combined.to_csv(combined_csv, index=False)
    print(f"Wrote {len(combined):,} rows → {combined_csv}")

    sample = combined.head(1000)
    sample.to_excel(combined_first1000, index=False)
    print(f"Wrote first {len(sample):,} rows → {combined_first1000}")


    def unmatched_counts(df, source_col, mapped_col, label):
        missing = df[source_col].notna() & df[mapped_col].isna()
        counts = (
            df.loc[missing, source_col]
            .value_counts()
            .rename_axis(source_col)
            .reset_index(name="Rows")
        )
        print(f"{len(counts)} unmatched {label} ({missing.sum():,} rows)")
        return counts


    unmatched_dsp = unmatched_counts(combined, "Third Party / DSP", "Third Party / DSP (Group)", "DSPs")
    unmatched_titles = unmatched_counts(combined, "Product Title", "Product Title (harmonised)", "titles")
    unmatched_countries = unmatched_counts(combined, "Country of Sale", "Country of Sale (harmonised)", "countries")
    unmatched_income_type = unmatched_counts(combined, "Tab Name", "Type of income", "income types")
    unmatched_source = unmatched_counts(combined, "Tab Name", "Source", "sources")


    def write_unmatched(counts, path, label):
        if counts.empty:
            print(f"No unmatched {label}; not writing {path.name}")
            if path.exists():
                path.unlink()
            return
        counts.to_excel(path, index=False)
        print(f"Wrote unmatched {label} → {path}")


    write_unmatched(unmatched_dsp, unmatched_dsp_xlsx, "DSPs")
    write_unmatched(unmatched_titles, unmatched_titles_xlsx, "titles")
    write_unmatched(unmatched_countries, unmatched_countries_xlsx, "countries")
    write_unmatched(unmatched_income_type, unmatched_income_type_xlsx, "income types")
    write_unmatched(unmatched_source, unmatched_source_xlsx, "sources")
# Out:
# Loaded from combined CSV; not rewriting the main CSV.

# %%
# Filter the combined file by Product Title (harmonised) and write xlsx.
# Set FILTER_TITLES in the first code cell, comma-separated, for example:
# FILTER_TITLES = "Tattoos - Live, Tabaluga"

titles = [t.strip() for t in str(FILTER_TITLES).split(",") if t.strip()]
if not titles:
    print("FILTER_TITLES is empty; not writing a filtered file.")
else:
    if "combined" in globals():
        filter_source = combined
    else:
        filter_source = pd.read_csv(combined_csv, low_memory=False)
        print(f"Loaded {len(filter_source):,} rows from {combined_csv}")

    col = "Product Title (harmonised)"
    if col not in filter_source.columns:
        raise KeyError(f"Column {col!r} is not in the combined file.")

    wanted = set(titles)
    filtered = filter_source[filter_source[col].isin(wanted)].copy()
    found = set(filtered[col].dropna().unique())
    missing = sorted(wanted - found)

    print(f"Filter titles ({len(wanted)}): {', '.join(titles)}")
    print(f"Matched rows: {len(filtered):,}")
    if len(filtered):
        print(filtered.groupby(col).size().rename("rows").to_string())
        net = pd.to_numeric(filtered["Net Amount"], errors="coerce").sum()
        print(f"Net Amount: {net:,.2f}")
    if missing:
        print("Not found in Product Title (harmonised):")
        for title in missing:
            print(f"  {title!r}")

    excel_max = 1_048_575
    if filtered.empty:
        print("No matching rows; not writing a file.")
    elif len(filtered) > excel_max:
        out = output_root / "Maffay_2018_2026Q1_filtered_titles.csv"
        filtered.to_csv(out, index=False)
        print(f"Too many rows for Excel; wrote CSV → {out}")
    else:
        filtered.to_excel(filtered_xlsx, index=False)
        print(f"Wrote {len(filtered):,} rows → {filtered_xlsx}")
# Out:
# FILTER_TITLES is empty; not writing a filtered file.

# %%
# Pivot only — run this cell after the combined CSV exists (or after the cells above).
# Change the index names (and optional columns) here; no need to re-run the combine.
pivot_index_1 = "Third Party / DSP (Group)" # None" # "Type of income"
pivot_index_2 = "Type of income" #"Third Party / DSP (Group)"  # set to None to drop this index
pivot_index_3 = None  # e.g. "Sales Month", or None to drop this index
pivot_index_4 = "Reporting Quarter" #"Third Party / DSP (Group)"  # set to None to drop this index
pivot_index_5 = "Sales Quarter" #"Third Party / DSP (Group)"  # set to None to drop this index
pivot_index_6 = "Product Title (harmonised)"  #"Third Party / DSP (Group)"  # set to None to drop this index
pivot_columns = None  # e.g. "Reporting Quarter", or None for a single total column

if "combined" in globals():
    pivot_source = combined
else:
    pivot_source = pd.read_csv(combined_csv, low_memory=False)
    print(f"Loaded {len(pivot_source):,} rows from {combined_csv}")

pivot_index = [name for name in [pivot_index_1, pivot_index_2, pivot_index_3, pivot_index_4, pivot_index_5, pivot_index_6] if name]
pivot_source = pivot_source.copy()


def fill_blank_category(series):
    text = series.astype("string").str.strip()
    missing = text.isna() | (text == "") | text.str.casefold().isin({"nan", "<na>", "none"})
    return text.mask(missing, "Blank")


for name in pivot_index + ([pivot_columns] if pivot_columns else []):
    if name in pivot_source.columns:
        pivot_source[name] = fill_blank_category(pivot_source[name])

pivot = pivot_source.pivot_table(
    index=pivot_index if len(pivot_index) > 1 else pivot_index[0],
    columns=pivot_columns,
    values=["Net Amount", "SAP Sales Units"], #"Net Amount, SAP Sales Units",
    fill_value=0,
    aggfunc="sum",
    margins=False,
    dropna=True #False,
)
pivot.to_excel(pivot_xlsx)
print(f"Wrote pivot → {pivot_xlsx}")
print(
    "Pivot table - 'Net Amount' by "
    + " / ".join(pivot_index)
    + (" / " + pivot_columns if pivot_columns else "")
    + ":"
)
pivot
# Out:
# Wrote pivot → /Users/johannesnatterer/Developer/_output/Maffay_2018_2026Q1_combined_pivot.xlsx
# Pivot table - 'Net Amount' by Third Party / DSP (Group) / Type of income / Reporting Quarter / Sales Quarter / Product Title (harmonised):
#                                                                                                                         Net Amount  \
# Third Party / DSP (Group)          Type of income Reporting Quarter Sales Quarter Product Title (harmonised)
# 7 Digital (global deal) (D|PJR5| ) Digital        2020 Q4           2019 Q3       Du                                      2.637416
#                                                                                   Du hattest keine Tränen mehr            1.318708
#                                                                                   Ein Bild kann nicht lachen so wie du    1.318708
#                                                                                   Leuchtturm                              1.480000
#                                                                                   MTV Unplugged                          24.800000
# ...                                                                                                                            ...
# mora qualitas (D|PQZ4)             Digital        2022 Q1           2022 Q1       Ich wollte nie erwachsen sein           0.020000
# sms.at, Austria                    Digital        2020 Q4           2020 Q3       Über sieben Brücken mußt du geh'n       1.000000
#                                                   2021 Q3           2021 Q3       Gelobtes Land                           1.000000
#                                                   2022 Q1           2022 Q1       Über sieben Brücken mußt du geh'n       2.000000
#                                                   2022 Q3           2022 Q3       Über sieben Brücken mußt du geh'n       1.000000
#
#                                                                                                                         SAP Sales Units
# Third Party / DSP (Group)          Type of income Reporting Quarter Sales Quarter Product Title (harmonised)
# 7 Digital (global deal) (D|PJR5| ) Digital        2020 Q4           2019 Q3       Du                                                2.0
#                                                                                   Du hattest keine Tränen mehr                      1.0
#                                                                                   Ein Bild kann nicht lachen so wie du              1.0
#                                                                                   Leuchtturm                                        1.0
#                                                                                   MTV Unplugged                                     2.0
# ...                                                                                                                                 ...
# mora qualitas (D|PQZ4)             Digital        2022 Q1           2022 Q1       Ich wollte nie erwachsen sein                     1.0
# sms.at, Austria                    Digital        2020 Q4           2020 Q3       Über sieben Brücken mußt du geh'n                 1.0
#                                                   2021 Q3           2021 Q3       Gelobtes Land                                     1.0
#                                                   2022 Q1           2022 Q1       Über sieben Brücken mußt du geh'n                 2.0
#                                                   2022 Q3           2022 Q3       Über sieben Brücken mußt du geh'n                 1.0
#
# [348767 rows x 2 columns]

# %%
if not RUN_SOURCE_CHECK:
    print("Source-file check skipped (RUN_SOURCE_CHECK = False).")
else:
    # Source-file check: combined Net Amount vs the amount column on each mapped tab.
    # Q1 2026 is checked first, then the older quarterly workbooks.
    # Trailing sheet totals (empty first column, amount = sum of lines) are dropped
    # the same way as in load_sheet. Run after the setup cell.
    # Uses `combined` if loaded, otherwise the CSV.

    TOLERANCE = 0.01  # EUR
    # Filename fragment to limit the run, or None for every as-received file.
    CHECK_FILE_FILTER = None


    def source_amount_series(df, group):
        if group == "P":
            return to_num(series(df, "WHOLESALE_VALUE"))
        if group == "Q":
            return to_num(series(df, "Net Amount"))
        if group in ("R", "S"):
            return physical_amount(df)
        if group in ("T", "U"):
            return to_num(series(df, "Netto-Ums#"))
        return pd.Series(dtype="float64")


    def source_amount_col(df, group):
        if group == "P":
            return find_col(df, "WHOLESALE_VALUE")
        if group == "Q":
            return find_col(df, "Net Amount")
        if group in ("R", "S"):
            return find_col(df, "Nettoumsatz Vormonat")
        if group in ("T", "U"):
            return find_col(df, "Netto-Ums#")
        return None


    if "combined" in globals():
        check_source = combined
    else:
        check_source = pd.read_csv(combined_csv, low_memory=False)
        print(f"Loaded {len(check_source):,} rows from {combined_csv}")

    check_source = check_source.copy()
    check_source["Net Amount"] = pd.to_numeric(check_source["Net Amount"], errors="coerce")
    combined_tot = (
        check_source.groupby(["File Name", "Tab Name"], dropna=False)["Net Amount"]
        .agg(combined_sum="sum", combined_n="count")
        .reset_index()
    )

    files = sorted(
        p
        for p in as_received.iterdir()
        if p.suffix.lower() in {".xlsx", ".xls", ".xlsm"}
        and not p.name.startswith("~$")
        and not skip_file(p)
    )
    if CHECK_FILE_FILTER:
        files = [p for p in files if CHECK_FILE_FILTER.lower() in p.name.lower()]
    files = sorted(files, key=lambda p: (p.name != control_xlsx.name, p.name.lower()))
    print(f"{len(files)} workbooks to check against the combined file\n")

    rows = []
    for i, path in enumerate(files, 1):
        print(f"[{i}/{len(files)}] {path.name}", flush=True)
        try:
            xl = pd.ExcelFile(path)
        except Exception as exc:
            print(f"  CANNOT OPEN: {exc}")
            rows.append(
                {
                    "File Name": path.name,
                    "Tab Name": "(file)",
                    "status": "CANNOT_OPEN",
                    "note": str(exc),
                }
            )
            continue
        seen = set()
        for sheet in xl.sheet_names:
            if skip_sheet(sheet):
                continue
            try:
                df = load_sheet(path, sheet)
            except Exception as exc:
                print(f"  SKIP {sheet!r}: {exc}")
                continue
            if df.empty or len(df.columns) < 4:
                continue
            group = classify_sheet(df, sheet)
            if group is None:
                looks_like_data = any(
                    k in sheet.lower() for k in ("phys", "dig", "gvl", "kopplung")
                )
                if looks_like_data:
                    print(f"  UNMAPPED {path.name} / {sheet!r}  cols={list(df.columns)[:8]}")
                continue
            amount = source_amount_series(df, group)
            source_sum = float(amount.sum(skipna=True))
            source_n = int(len(df))
            match = combined_tot[
                (combined_tot["File Name"] == path.name) & (combined_tot["Tab Name"] == sheet)
            ]
            combined_sum = float(match["combined_sum"].sum()) if len(match) else 0.0
            combined_n = int(match["combined_n"].sum()) if len(match) else 0
            diff = combined_sum - source_sum
            if abs(diff) <= TOLERANCE and combined_n == source_n:
                status = "OK"
            elif abs(diff) <= TOLERANCE:
                status = "SUM_OK"
            else:
                status = "MISMATCH"
            if status != "OK":
                print(
                    f"  {status} {sheet!r}  source={source_sum:,.2f} n={source_n}  "
                    f"combined={combined_sum:,.2f} n={combined_n}  diff={diff:,.4f}"
                )
            rows.append(
                {
                    "File Name": path.name,
                    "Tab Name": sheet,
                    "Source Group": group,
                    "Amount column": source_amount_col(df, group),
                    "source_n": source_n,
                    "combined_n": combined_n,
                    "source_sum": source_sum,
                    "combined_sum": combined_sum,
                    "Difference": diff,
                    "status": status,
                    "is_q1_2026": path.name == control_xlsx.name,
                }
            )
            seen.add(sheet)
        extra = set(combined_tot.loc[combined_tot["File Name"] == path.name, "Tab Name"]) - seen
        for tab in sorted(extra):
            extra_sum = float(
                combined_tot.loc[
                    (combined_tot["File Name"] == path.name) & (combined_tot["Tab Name"] == tab),
                    "combined_sum",
                ].sum()
            )
            print(f"  EXTRA IN COMBINED {tab!r}  combined={extra_sum:,.2f}")
            rows.append(
                {
                    "File Name": path.name,
                    "Tab Name": tab,
                    "combined_sum": extra_sum,
                    "status": "EXTRA_IN_COMBINED",
                    "is_q1_2026": path.name == control_xlsx.name,
                }
            )

    detail = pd.DataFrame(rows)
    q1 = detail[detail["is_q1_2026"] == True].copy() if "is_q1_2026" in detail.columns else detail.iloc[0:0]
    older = detail[detail["is_q1_2026"] != True].copy() if "is_q1_2026" in detail.columns else detail
    by_file = (
        detail.groupby("File Name", dropna=False)[["source_sum", "combined_sum", "source_n", "combined_n"]]
        .sum(min_count=1)
        .reset_index()
    )
    by_file["Difference"] = by_file["combined_sum"] - by_file["source_sum"]
    by_file["Match"] = by_file["Difference"].abs() <= TOLERANCE

    n_ok = int((detail["status"] == "OK").sum()) if len(detail) else 0
    n_bad = int((detail["status"] != "OK").sum()) if len(detail) else 0

    print("\n===== Q1 2026 source tabs vs combined =====")
    if len(q1):
        print(
            q1[
                [
                    "Tab Name",
                    "Source Group",
                    "Amount column",
                    "source_n",
                    "combined_n",
                    "source_sum",
                    "combined_sum",
                    "Difference",
                    "status",
                ]
            ].to_string(index=False)
        )
        print(
            f"\nQ1 2026 source:    {q1['source_sum'].sum():,.2f}  ({int(q1['source_n'].sum()):,} rows)"
        )
        print(
            f"Q1 2026 combined:  {q1['combined_sum'].sum():,.2f}  ({int(q1['combined_n'].sum()):,} rows)"
        )
        print(f"Q1 2026 tabs OK:   {int((q1['status'] == 'OK').sum())} / {len(q1)}")
    else:
        print("Q1 2026 file was not in this check run.")

    print("\n===== All files =====")
    print(by_file.to_string(index=False))
    print(f"\nTabs OK: {n_ok} / {len(detail)}   (not OK: {n_bad})")
    print(f"Source tabs total:    {detail['source_sum'].sum():,.2f}")
    print(f"Combined tabs total:  {detail['combined_sum'].sum():,.2f}")
    print(f"Combined file total:  {check_source['Net Amount'].sum():,.2f}")

    mismatches = detail[detail["status"] != "OK"]
    if len(mismatches):
        print("\nTabs that did not match:")
        print(
            mismatches[
                [
                    "File Name",
                    "Tab Name",
                    "source_n",
                    "combined_n",
                    "source_sum",
                    "combined_sum",
                    "Difference",
                    "status",
                ]
            ].to_string(index=False)
        )
    else:
        print("\nAll mapped source tabs match the combined file (sum and row count).")

    with pd.ExcelWriter(check_xlsx, engine="openpyxl") as writer:
        if len(q1):
            q1.drop(columns=["is_q1_2026"], errors="ignore").to_excel(
                writer, sheet_name="Q1 2026 tabs", index=False
            )
        by_file.to_excel(writer, sheet_name="By file", index=False)
        detail.drop(columns=["is_q1_2026"], errors="ignore").to_excel(
            writer, sheet_name="By tab", index=False
        )
        if len(mismatches):
            mismatches.drop(columns=["is_q1_2026"], errors="ignore").to_excel(
                writer, sheet_name="Mismatches", index=False
            )

    print(f"\nWrote check → {check_xlsx}")
    by_file
# Out:
# Source-file check skipped (RUN_SOURCE_CHECK = False).
