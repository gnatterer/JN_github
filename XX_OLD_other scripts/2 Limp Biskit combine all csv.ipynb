# %%
import pandas as pd
import os 

# inputs
only_pivot = 0
directory = '../Excel_Download - individual files/csv'
headerfilename = 'combined_header.xlsx'
pivotfilename =  'combined_pivot.xlsx'
outputfilename = 'Limp_Biskit_csv_combined.csv'

# %%
def find_xls_files(directory):
    xls_files = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith('.csv'):
                xls_files.append(os.path.join(root, file))
    return xls_files 
    
def Import_and_combine_single_files(directory): 
    print("Reading files and combining them in one data frame")
    listoffiles = find_xls_files(directory)
    print(f"\nTotal number of 'xls' files found is {len(listoffiles)}")
    for xls_file in listoffiles:
        print(xls_file)
    data_frames = []
    for file in listoffiles:
        print(f"\nAccessing {file}")
        try:
            df = pd.read_csv(file, header=0, skiprows=7,low_memory=False)
            activity_index = df[df.iloc[:, 0] == 'Activity'].index[0]
            df = df.iloc[:activity_index - 1] # deletes all lines below "activity" and also the one including and above
        except ValueError as e:
            print(f"Error reading {file}: {e}")
        except Exception as e:
            print(f"Unexpected error reading {file}: {e}")
        print(f"It has {df.shape[0]} rows and {len(df.columns)} columns.")
        print(f"Royalty: {df['Net_roy_earn'].sum()}. Units: {df['Units'].sum()}")
        filename = os.path.splitext(os.path.basename(file))[0]
        sheet_name = filename.replace("ArtistRoyaltyStatements", "")
        df['Filename']= sheet_name   
        data_frames.append(df)    
    df_comb = pd.concat(data_frames, ignore_index=True)
    print(f"\nThe combined DataFrame df_1_4 has {df_comb.shape[0]} rows and {len(df_comb.columns)} columns.")
    print(f"Royalty: {df_comb['Net_roy_earn'].sum()}. Units: {df_comb['Units'].sum()}")
    return df_comb

def compute_receipts(row):
    if pd.isna(row['Receipts.Computed']):
    #if row['Receipts.Computed'] == 'N/A':
        return row['Price'] * row['Units']
    return row['Receipts.Computed']

def convert_percentage(value):
    return float(value.strip('%')) / 100

# %%
if only_pivot == 1:
    df = pd.read_csv(outputfilename)
else: 
    df = Import_and_combine_single_files(directory)
    df = df.drop(df.columns[27:38], axis=1)
    df.info()
    df.to_csv(outputfilename, index=False)
# Out:
# Reading files and combining them in one data frame
#
# Total number of 'xls' files found is 12
# Excel_Download/csv/2024Q2 Limp Bizkit- LP1-3 96 AGMNT ArtistRoyaltyStatements.csv
# Excel_Download/csv/2021Q4 Limp Bizkit- LP 1-3 96 AGMNT ArtistRoyaltyStatements.csv
# Excel_Download/csv/2021Q2 Limp Bizkit- LP1-3 96 AGMT ArtistRoyaltyStatements.csv
# Excel_Download/csv/2016Q4 Limp Bizkit-LP1-3 96 AGMNT ArtistRoyaltyStatements.csv
# Excel_Download/csv/2017Q4 Limp BizkitLP1-3 96 AGMNT ArtistRoyaltyStatements.csv
# Excel_Download/csv/2022Q4 Limp Bizkit- LP1-3 96 AGMNT ArtistRoyaltyStatements.csv
# Excel_Download/csv/2020Q4 Limp Bizkit-LP1-3 96 AGMT ArtistRoyaltyStatements.csv
# Excel_Download/csv/2023Q2 Limp Bizkit- LP1-3 96 AGMT ArtistRoyaltyStatements.csv
# Excel_Download/csv/2016Q2 Limp Bizkit-LP4 Result'00 AGM ArtistRoyaltyStatements.csv
# Excel_Download/csv/2023Q4 Limp Bizkit- LP1-3 96 AGMNT ArtistRoyaltyStatements.csv
# Excel_Download/csv/2022Q2 Limp Bizkit-LP 1-3 96 AGMNT ArtistRoyaltyStatements.csv
# Excel_Download/csv/2019Q2 Limp Bizkit-LP1-3 96 AGMNT ArtistRoyaltyStatements.csv
#
# Accessing Excel_Download/csv/2024Q2 Limp Bizkit- LP1-3 96 AGMNT ArtistRoyaltyStatements.csv
# It has 240516 rows and 38 columns.
# Royalty: 466647.90000000014. Units: 5139744154.0
#
# Accessing Excel_Download/csv/2021Q4 Limp Bizkit- LP 1-3 96 AGMNT ArtistRoyaltyStatements.csv
# It has 161183 rows and 38 columns.
# Royalty: 264326.46. Units: 1965641212.0
#
# Accessing Excel_Download/csv/2021Q2 Limp Bizkit- LP1-3 96 AGMT ArtistRoyaltyStatements.csv
# It has 134903 rows and 38 columns.
# Royalty: 211086.00000000003. Units: 1684114278.0
#
# Accessing Excel_Download/csv/2016Q4 Limp Bizkit-LP1-3 96 AGMNT ArtistRoyaltyStatements.csv
# It has 67919 rows and 38 columns.
# Royalty: 122329.99. Units: 590479137.0
#
# Accessing Excel_Download/csv/2017Q4 Limp BizkitLP1-3 96 AGMNT ArtistRoyaltyStatements.csv
# It has 67099 rows and 38 columns.
# Royalty: 153362.12. Units: 871977723.0
#
# Accessing Excel_Download/csv/2022Q4 Limp Bizkit- LP1-3 96 AGMNT ArtistRoyaltyStatements.csv
# It has 161658 rows and 38 columns.
# Royalty: 304102.12000000005. Units: 2933492129.0
#
# Accessing Excel_Download/csv/2020Q4 Limp Bizkit-LP1-3 96 AGMT ArtistRoyaltyStatements.csv
# It has 132235 rows and 38 columns.
# Royalty: 187889.99999999994. Units: 1635501948.0
#
# Accessing Excel_Download/csv/2023Q2 Limp Bizkit- LP1-3 96 AGMT ArtistRoyaltyStatements.csv
# It has 186319 rows and 38 columns.
# Royalty: 380897.7300000002. Units: 4036230959.0
#
# Accessing Excel_Download/csv/2016Q2 Limp Bizkit-LP4 Result'00 AGM ArtistRoyaltyStatements.csv
# It has 5423 rows and 38 columns.
# Royalty: 42501.130000000005. Units: 36259957.0
#
# Accessing Excel_Download/csv/2023Q4 Limp Bizkit- LP1-3 96 AGMNT ArtistRoyaltyStatements.csv
# It has 222538 rows and 38 columns.
# Royalty: 408694.65. Units: 5393087802.0
#
# Accessing Excel_Download/csv/2022Q2 Limp Bizkit-LP 1-3 96 AGMNT ArtistRoyaltyStatements.csv
# It has 168163 rows and 38 columns.
# Royalty: 280435.63. Units: 4462476376.0
#
# Accessing Excel_Download/csv/2019Q2 Limp Bizkit-LP1-3 96 AGMNT ArtistRoyaltyStatements.csv
# It has 114051 rows and 38 columns.
# Royalty: 171515.44000000003. Units: 1724984539.0
#
# The combined DataFrame df_1_4 has 1662007 rows and 39 columns.
# Royalty: 2993789.169999999. Units: 30473990214.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1662007 entries, 0 to 1662006
# Data columns (total 28 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   RoySys        1662007 non-null  object
#  1   Acct_no       1662007 non-null  object
#  2   Acct_Qtr      1662007 non-null  object
#  3   Seq_no        1662007 non-null  object
#  4   Payee_no      1662007 non-null  object
#  5   Vendor_no     240516 non-null   object
#  6   Group_no      1662007 non-null  object
#  7   Source        1662007 non-null  object
#  8   Title         1662007 non-null  object
#  9   DSP           1627488 non-null  object
#  10  Sales Type    1662007 non-null  object
#  11  SC            1661995 non-null  object
#  12  Price Level   1662007 non-null  object
#  13  Sales Date    1642149 non-null  object
#  14  Selection     1662007 non-null  object
#  15  Config        1662007 non-null  object
#  16  Contract      1662007 non-null  object
#  17  Pr_code       1662007 non-null  object
#  18  Price         1662007 non-null  float64
#  19  Pckg_rate     1662007 non-null  object
#  20  Roy_Rate      1662007 non-null  float64
#  21  Part %        1662007 non-null  object
#  22  Eff_rate      1662007 non-null  float64
#  23  Units         1662007 non-null  float64
#  24  Receipts $    1501645 non-null  float64
#  25  Tax_rate      1662007 non-null  object
#  26  Net_roy_earn  1662007 non-null  float64
#  27  Filename      1662007 non-null  object
# dtypes: float64(6), object(22)
# memory usage: 355.0+ MB

# %%
"""
df_filter = df

#df_filter = df[df['Statement Period'] == '2023-H2'].iloc[:, :] 
#df_filter = df_filter[df_filter['Account No.'] == 'S10002212'].iloc[:, :] 



print(f"The filtered dataframe has {df_filter.shape[0]} rows and {len(df_filter.columns)} columns.")


print("\nColumn names are:")
for column in df_filter.columns:
    print(column)


val1 = 'Receipts.Computed'
val2 = 'Units'
val3 = 'Gross_roy_earn'
val4 = 'Net_roy_earn'

val1crit = 'sum'
val2crit = 'sum'
val3crit = 'sum'
val4crit = 'sum'
val5crit = 'sum'


x0 = 'Filename'
x1 = 'RoySys'
x2 = 'Acct_no'
x3 = 'Acct_Qtr'
x4 = 'Seq_no'
x5 = 'Payee_no'
x6 = 'Vendor_no'
x7 = 'Group_no'
x8 = 'Source'
x9 = 'Title'
x10 = 'DSP'
x11 = 'Sales Type'
x12 = 'SC'
x13 = 'Price Level'
x14 = 'Sales Date'
x15 = 'Selection'
x16 = 'Config'
x17 = 'Contract'
x18 = 'Pr_code'
x19 = 'Price'
x20 = 'Pckg_rate'
x21 = 'Roy_Rate'
x22 = 'Part %'
x23 = 'Eff_rate'
x24 = 'Units'
x25 = 'Receipts $'
x26 = 'Tax_rate'
x27 = 'Net_roy_earn'
x28 = 'Receipts. Computed'
x29 = 'Gross_roy_earn'

sortby = val2


pivot = pd.pivot_table(df_filter, 
                        values=[val1,val2,val3,val4],
                        index=[x0], 
                        #columns= [x11],
                        fill_value='',
                        margins= True,
                        aggfunc={val1:val1crit, val2:val2crit, val3:val3crit,val4:val4crit})
pivot = pivot.ffill(axis=1).bfill(axis=1)
pivot.to_excel(pivotfilename, engine='openpyxl', index=True)
pivot
"""
# Out:
# '\ndf_filter = df\n\n#df_filter = df[df[\'Statement Period\'] == \'2023-H2\'].iloc[:, :] \n#df_filter = df_filter[df_filter[\'Account No.\'] == \'S10002212\'].iloc[:, :] \n\n\n\nprint(f"The filtered dataframe has {df_filter.shape[0]} rows and {len(df_filter.columns)} columns.")\n\n\nprint("\nColumn names are:")\nfor column in df_filter.columns:\n    print(column)\n\n\nval1 = \'Receipts.Computed\'\nval2 = \'Units\'\nval3 = \'Gross_roy_earn\'\nval4 = \'Net_roy_earn\'\n\nval1crit = \'sum\'\nval2crit = \'sum\'\nval3crit = \'sum\'\nval4crit = \'sum\'\nval5crit = \'sum\'\n\n\nx0 = \'Filename\'\nx1 = \'RoySys\'\nx2 = \'Acct_no\'\nx3 = \'Acct_Qtr\'\nx4 = \'Seq_no\'\nx5 = \'Payee_no\'\nx6 = \'Vendor_no\'\nx7 = \'Group_no\'\nx8 = \'Source\'\nx9 = \'Title\'\nx10 = \'DSP\'\nx11 = \'Sales Type\'\nx12 = \'SC\'\nx13 = \'Price Level\'\nx14 = \'Sales Date\'\nx15 = \'Selection\'\nx16 = \'Config\'\nx17 = \'Contract\'\nx18 = \'Pr_code\'\nx19 = \'Price\'\nx20 = \'Pckg_rate\'\nx21 = \'Roy_Rate\'\nx22 = \'Part %\'\nx23 = \'Eff_rate\'\nx24 = \'Units\'\nx25 = \'Receipts $\'\nx26 = \'Tax_rate\'\nx27 = \'Net_roy_earn\'\nx28 = \'Receipts. Computed\'\nx29 = \'Gross_roy_earn\'\n\nsortby = val2\n\n\npivot = pd.pivot_table(df_filter, \n                        values=[val1,val2,val3,val4],\n                        index=[x0], \n                        #columns= [x11],\n                        fill_value=\'\',\n                        margins= True,\n                        aggfunc={val1:val1crit, val2:val2crit, val3:val3crit,val4:val4crit})\npivot = pivot.ffill(axis=1).bfill(axis=1)\npivot.to_excel(pivotfilename, engine=\'openpyxl\', index=True)\npivot\n'
