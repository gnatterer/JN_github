# %%
import pandas as pd

# Load the combined file
combined_file = "../../50 KM Group/Royalties/Statements/Other artists/Sally and Lam/SallyLam_2022h2_2025H2.csv"
df = pd.read_csv(combined_file)

# List of product titles to keep
titles_to_keep = [
    "XIAO SA ZOU YI HUI",
    "CENG JING XIN TONG",
    "CHUN FENG QIU YU",
    "QING REN ZHI JI",
    "GAN AI GAN ZUO",
    "ZHU FU",
    "SHUI NENG MING BAI WO",
    "NAN ER DANG ZI QIANG",
    "DARE TO LOVE ME",
    "CENG JING XIN TONG [RINGBACK]",
    "ZHEN XIN ZHEN YI GUO YI SHANG",
    "MR. STRONG MAN",
    "XUAN ZE",
    "QIU QU QIU LAI",
    "QING REN ZHI JI (AUDIO RBT)",
    "ZHEN ZHONG",
    "CHANG LU MAN MAN BAN NI CHUANG",
    "SHU ZI REN SHENG"
]

# Filter the DataFrame
sub_df = df[df["Product Title"].isin(titles_to_keep)]

# Save the subfile to Excel
sub_df.to_excel("../../50 KM Group/Royalties/Statements/Karen/_output/SallyLam_2022H2_2025H2_subfile.xlsx", index=False)

# Print confirmation and stats
print("Subfile created: subfile.xlsx")
print("Number of rows in subfile:", len(sub_df))
print("Columns in subfile:", list(sub_df.columns))

# Optional: show totals for Sale Units and Royalty Payable in the subfile
if "Sale Units" in sub_df.columns:
    print("Total Sale Units in subfile:", sub_df["Sale Units"].sum())
if "Royalty Payable" in sub_df.columns:
    print("Total Royalty Payable in subfile:", sub_df["Royalty Payable"].sum())
# Out:
# /var/folders/r4/jcfnn_jn7d78r15gxq27mq2m0000gn/T/ipykernel_37604/4012601703.py:5: DtypeWarning: Columns (52,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(combined_file)
# Subfile created: subfile.xlsx
# Number of rows in subfile: 531355
# Columns in subfile: ['SourceFile', 'Recdate Month ID', 'Repdate Month ID', 'Catalog Number', 'Share Tracks', 'Share Total Tracks', 'Share Time', 'Share Total Time', 'Sale Units', 'Price', 'Royalty Base', 'Unit Rate', 'Royalty Payable', 'Account', 'Packaging Rate', 'Royalty Rate', 'Sales PCT', 'Subsid PCT', 'Revenue Rate', 'Price Code', 'Start Period', 'End Period', 'WHT Rate', 'Exch Rate', 'Escalation Rate', 'Location', 'Digital Service Provider(DSP)', 'Product Type', 'Account Name', 'Product Title', 'Price Desc', 'Payee', 'Company Name', 'Company Addr1', 'Company Addr2', 'Company Addr3', 'Company Addr4', 'Tune Code', 'Tune Title', 'Territory Code', 'Config Type', 'Option Period Code', 'Country', 'Dist. Ch.', 'DSP Number', 'Product Type Code', 'Dist Chan Desc', 'Artist Name', 'GPID', 'ISRC', 'Config', 'Receipts', 'Option Period Desc', 'Local Product Number']
# Total Sale Units in subfile: 2339370384
# Total Royalty Payable in subfile: 2721702.1592645906
