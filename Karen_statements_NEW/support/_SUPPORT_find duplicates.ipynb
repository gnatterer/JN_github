# %%
lookup_song = '../../../50 KM Group/Royalties/Statements/Karen/All labels combined/lookup_tables/global_lookup_platform.csv'
#lookup_song = '../../50 KM Group/royalties/statements/Karen/Rock Music/Consolidated statements/lookup_tables/Rock_lookup_ISRC_song_album_albumtype copy.xlsx'
import pandas as pd

def readfile(file):
    df = pd.read_csv(file)
    #df = pd.read_excel(file, sheet_name="Data")
    print(f"The dataframe '{file}' has {df.shape[0]} rows and {len(df.columns)} columns.")
    return df

df_lookup_song = readfile(lookup_song)
duplicates = df_lookup_song[df_lookup_song.duplicated(subset=['Platform_original'], keep=False)]
print(duplicates)
# Out:
# The dataframe '../../../50 KM Group/Royalties/Statements/Karen/All labels combined/lookup_tables/global_lookup_platform.csv' has 456 rows and 2 columns.
#     Platform_original                       Platform
# 20            Anghami  Anghami Digi Music (D|PGC4| )
# 21            Anghami  Anghami Digi Music (D|PGC4| )
# 46                AWA                 AWA (D|PKZ0| )
# 47                AWA                 AWA (D|PKZ0| )
# 177        Label Gate                     Label Gate
# 178        Label Gate                     Label Gate
